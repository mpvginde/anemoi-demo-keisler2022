# %% [markdown]
# # Anemoi training configurations
#
# Anemoi adopts a config-driven approach to development, and training new models makes no exception. In this notebook, we will have a brief overview of how the anemoi-training configuration system works. The configuration controls every aspect of the program, including:
#
# - data sources, data loading
# - model architectures
# - optimization hyperparameters
# - distributed training strategy
# - training diagnostics
#
# and a lot more!

# %% [markdown]
# ## Generate default configs
#
# Start by generating a configuration directory with

# %%
# !anemoi-training config generate --output ../configs/training
# Out:
# 2025-10-23 11:59:18 INFO Generating configs, please wait.
# 2025-10-23 11:59:18 INFO File ../configs/training/ensemble_crps.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/debug.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/stretched.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/diffusion.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/interpolator.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/hierarchical.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/lam.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/config.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/data/zarr.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/dataloader/native_grid.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/model/transformer_ens.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/model/transformer_diffusiontend.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/model/transformer.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/model/graphtransformer_ens.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/model/gnn.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/model/graphtransformer_diffusion.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/model/transformer_diffusion.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/model/transformer_transformermapper.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/model/graphtransformer.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/model/graphtransformer_diffusiontend.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/datamodule/single.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/datamodule/ens.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/training/stretched.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/training/diffusion.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/training/interpolator.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/training/ensemble.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/training/default.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/training/lam.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/graph/encoder_decoder_only.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/graph/hierarchical_2level.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/graph/hierarchical_3level.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/graph/limited_area.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/graph/multi_scale.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/graph/stretched_grid.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/graph/existing.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/graph/existing_graph.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/diagnostics/evaluation.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/hardware/example.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/hardware/slurm.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/training/scalers/stretched.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/training/scalers/global.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/training/scalers/lam.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/diagnostics/callbacks/placeholder.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/diagnostics/callbacks/rollout_eval.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/diagnostics/benchmark_profiler/detailed.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/diagnostics/benchmark_profiler/simple.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/diagnostics/plot/detailed.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/diagnostics/plot/simple.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/diagnostics/plot/rollout_eval.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/hardware/files/example.yaml already exists, skipping
# 2025-10-23 11:59:18 INFO File ../configs/training/hardware/paths/example.yaml already exists, skipping

# %% [markdown]
# This will contain some default configs to run the training. You can find more about how the training configuration works in the ["Configuration basics"](https://anemoi.readthedocs.io/projects/training/en/latest/user-guide/hydra-intro.html) section of the anemoi-training documentation.
#
# In the top folder of `configs/training` you will find a collection of configs that anemoi contributors are currently using. Quite some diversity! For this tutorial, we will create our own config starting from `config.yaml`

# %% [markdown]
# ## Our first training config
#
# Let's inspect our training configuration

# %%
import yaml
from pprint import pprint

with open("../configs/training/config.yaml") as f:
    config = yaml.safe_load(f)

pprint(config)
# Out:
# {'config_validation': True,
#  'defaults': [{'data': 'zarr'},
#               {'dataloader': 'native_grid'},
#               {'diagnostics': 'evaluation'},
#               {'datamodule': 'single'},
#               {'hardware': 'example'},
#               {'graph': 'multi_scale'},
#               {'model': 'gnn'},
#               {'training': 'default'},
#               '_self_']}

# %% [markdown]
# for now, we only have some defaults. Defaults are themselves YAML files and they are resolved into the full configuration with [hydra](https://github.com/facebookresearch/hydra), a framework for handling hierarchically structured configs. Let's try to compose the full config.

# %%
from omegaconf import OmegaConf
from pprint import pprint
from anemoi_demo_keisler2022.helpers import compose_config, load_config

composed_config = compose_config("../configs/training", "config")

pprint(OmegaConf.to_container(composed_config))
# Out:
# {'config_validation': True,
#  'data': {'diagnostic': ['tp', 'cp'],
#           'forcing': ['cos_latitude',
#                       'cos_longitude',
#                       'sin_latitude',
#                       'sin_longitude',
#                       'cos_julian_day',
#                       'cos_local_time',
#                       'sin_julian_day',
#                       'sin_local_time',
#                       'insolation',
#                       'lsm',
#                       'sdor',
#                       'slor',
#                       'z'],
#           'format': 'zarr',
#           'frequency': '6h',
#           'normalizer': {'default': 'mean-std',
#                          'max': ['sdor', 'slor', 'z'],
#                          'min-max': None,
#                          'none': ['cos_latitude',
#                                   'cos_longitude',
#                                   'sin_latitude',
#                                   'sin_longitude',
#                                   'cos_julian_day',
#                                   'cos_local_time',
#                                   'sin_julian_day',
#                                   'sin_local_time',
#                                   'insolation',
#                                   'lsm'],
#                          'std': ['tp']},
#           'num_features': None,
#           'processors': {'normalizer': {'_target_': 'anemoi.models.preprocessing.normalizer.InputNormalizer',
#                                         'config': '${data.normalizer}'}},
#           'timestep': '6h'},
#  'dataloader': {'batch_size': {'test': 4, 'training': 2, 'validation': 4},
#                 'dataset': '${hardware.paths.data}/${hardware.files.dataset}',
#                 'grid_indices': {'_target_': 'anemoi.training.data.grid_indices.FullGrid',
#                                  'nodes_name': '${graph.data}'},
#                 'limit_batches': {'test': 20,
#                                   'training': None,
#                                   'validation': None},
#                 'num_workers': {'test': 8, 'training': 8, 'validation': 8},
#                 'pin_memory': True,
#                 'prefetch_factor': 2,
#                 'read_group_size': '${hardware.num_gpus_per_model}',
#                 'test': {'dataset': '${dataloader.dataset}',
#                          'drop': [],
#                          'end': None,
#                          'frequency': '${data.frequency}',
#                          'start': 2022},
#                 'training': {'dataset': '${dataloader.dataset}',
#                              'drop': [],
#                              'end': 2020,
#                              'frequency': '${data.frequency}',
#                              'start': None},
#                 'validation': {'dataset': '${dataloader.dataset}',
#                                'drop': [],
#                                'end': 2021,
#                                'frequency': '${data.frequency}',
#                                'start': 2021},
#                 'validation_rollout': 1},
#  'datamodule': {'_target_': 'anemoi.training.data.datamodule.AnemoiDatasetsDataModule'},
#  'diagnostics': {'benchmark_profiler': {'memory': {'enabled': True,
#                                                    'extra_plots': False,
#                                                    'steps': 5,
#                                                    'trace_rank0_only': False,
#                                                    'warmup': 2},
#                                         'model_summary': {'enabled': True},
#                                         'snapshot': {'enabled': True,
#                                                      'steps': 4,
#                                                      'warmup': 0},
#                                         'speed': {'enabled': True},
#                                         'system': {'enabled': True},
#                                         'time': {'enabled': True,
#                                                  'verbose': False}},
#                  'callbacks': [],
#                  'check_val_every_n_epoch': 1,
#                  'checkpoint': {'every_n_epochs': {'num_models_saved': -1,
#                                                    'save_frequency': 1},
#                                 'every_n_minutes': {'num_models_saved': 3,
#                                                     'save_frequency': 30},
#                                 'every_n_train_steps': {'num_models_saved': 0,
#                                                         'save_frequency': None}},
#                  'debug': {'anomaly_detection': False},
#                  'enable_checkpointing': True,
#                  'enable_progress_bar': True,
#                  'log': {'interval': 100,
#                          'mlflow': {'authentication': False,
#                                     'enabled': True,
#                                     'expand_hyperparams': ['config'],
#                                     'experiment_name': 'aiwcas2025-anemoi-demo',
#                                     'http_max_retries': 35,
#                                     'max_params_length': 2000,
#                                     'offline': False,
#                                     'on_resume_create_child': True,
#                                     'project_name': 'Anemoi',
#                                     'run_name': None,
#                                     'system': True,
#                                     'terminal': True,
#                                     'tracking_uri': 'https://servicedevt.meteoswiss.ch/mlstore'},
#                          'tensorboard': {'enabled': False},
#                          'wandb': {'enabled': False,
#                                    'entity': '???',
#                                    'gradients': False,
#                                    'log_model': False,
#                                    'offline': False,
#                                    'parameters': False,
#                                    'project': 'Anemoi'}},
#                  'plot': {'asynchronous': True,
#                           'callbacks': [{'_target_': 'anemoi.training.diagnostics.callbacks.plot.GraphTrainableFeaturesPlot',
#                                          'every_n_epochs': 5},
#                                         {'_target_': 'anemoi.training.diagnostics.callbacks.plot.PlotLoss',
#                                          'every_n_batches': '${diagnostics.plot.frequency.batch}',
#                                          'parameter_groups': {'moisture': ['tp',
#                                                                            'cp',
#                                                                            'tcw'],
#                                                               'sfc_wind': ['10u',
#                                                                            '10v']}},
#                                         {'_target_': 'anemoi.training.diagnostics.callbacks.plot.PlotSample',
#                                          'accumulation_levels_plot': [0,
#                                                                       0.05,
#                                                                       0.1,
#                                                                       0.25,
#                                                                       0.5,
#                                                                       1,
#                                                                       1.5,
#                                                                       2,
#                                                                       3,
#                                                                       4,
#                                                                       5,
#                                                                       6,
#                                                                       7,
#                                                                       100],
#                                          'colormaps': '${diagnostics.plot.colormaps}',
#                                          'every_n_batches': '${diagnostics.plot.frequency.batch}',
#                                          'parameters': '${diagnostics.plot.parameters}',
#                                          'per_sample': 6,
#                                          'precip_and_related_fields': '${diagnostics.plot.precip_and_related_fields}',
#                                          'sample_idx': '${diagnostics.plot.sample_idx}'},
#                                         {'_target_': 'anemoi.training.diagnostics.callbacks.plot.PlotSpectrum',
#                                          'every_n_batches': '${diagnostics.plot.frequency.batch}',
#                                          'parameters': ['z_500',
#                                                         'tp',
#                                                         '2t',
#                                                         '10u',
#                                                         '10v'],
#                                          'sample_idx': '${diagnostics.plot.sample_idx}'},
#                                         {'_target_': 'anemoi.training.diagnostics.callbacks.plot.PlotHistogram',
#                                          'every_n_batches': '${diagnostics.plot.frequency.batch}',
#                                          'parameters': ['z_500',
#                                                         'tp',
#                                                         '2t',
#                                                         '10u',
#                                                         '10v'],
#                                          'precip_and_related_fields': '${diagnostics.plot.precip_and_related_fields}',
#                                          'sample_idx': '${diagnostics.plot.sample_idx}'}],
#                           'colormaps': {'default': {'_target_': 'anemoi.training.utils.custom_colormaps.MatplotlibColormap',
#                                                     'name': 'viridis'},
#                                         'error': {'_target_': 'anemoi.training.utils.custom_colormaps.MatplotlibColormap',
#                                                   'name': 'bwr'},
#                                         'precip': {'_target_': 'anemoi.training.utils.custom_colormaps.MatplotlibColormapClevels',
#                                                    'clevels': ['#ffffff',
#                                                                '#04e9e7',
#                                                                '#019ff4',
#                                                                '#0300f4',
#                                                                '#02fd02',
#                                                                '#01c501',
#                                                                '#008e00',
#                                                                '#fdf802',
#                                                                '#e5bc00',
#                                                                '#fd9500',
#                                                                '#fd0000',
#                                                                '#d40000',
#                                                                '#bc0000',
#                                                                '#f800fd'],
#                                                    'variables': '${diagnostics.plot.precip_and_related_fields}'}},
#                           'datashader': True,
#                           'frequency': {'batch': 750, 'epoch': 5},
#                           'parameters': ['z_500',
#                                          't_850',
#                                          'u_850',
#                                          'v_850',
#                                          '2t',
#                                          '10u',
#                                          '10v',
#                                          'sp',
#                                          'tp',
#                                          'cp'],
#                           'precip_and_related_fields': ['tp', 'cp'],
#                           'sample_idx': 0},
#                  'print_memory_summary': False,
#                  'profiler': False},
#  'graph': {'attributes': {'edges': {'edge_dirs': {'_target_': 'anemoi.graphs.edges.attributes.EdgeDirection',
#                                                   'norm': 'unit-std'},
#                                     'edge_length': {'_target_': 'anemoi.graphs.edges.attributes.EdgeLength',
#                                                     'norm': 'unit-std'}},
#                           'nodes': {'area_weight': {'_target_': 'anemoi.graphs.nodes.attributes.SphericalAreaWeights',
#                                                     'fill_value': 0,
#                                                     'norm': 'unit-max'}}},
#            'data': 'data',
#            'edges': [{'attributes': '${graph.attributes.edges}',
#                       'edge_builders': [{'_target_': 'anemoi.graphs.edges.CutOffEdges',
#                                          'cutoff_factor': 0.6,
#                                          'source_mask_attr_name': None,
#                                          'target_mask_attr_name': None}],
#                       'source_name': '${graph.data}',
#                       'target_name': '${graph.hidden}'},
#                      {'attributes': '${graph.attributes.edges}',
#                       'edge_builders': [{'_target_': 'anemoi.graphs.edges.MultiScaleEdges',
#                                          'scale_resolutions': '${graph.nodes.hidden.node_builder.resolution}',
#                                          'source_mask_attr_name': None,
#                                          'target_mask_attr_name': None,
#                                          'x_hops': 1}],
#                       'source_name': '${graph.hidden}',
#                       'target_name': '${graph.hidden}'},
#                      {'attributes': '${graph.attributes.edges}',
#                       'edge_builders': [{'_target_': 'anemoi.graphs.edges.KNNEdges',
#                                          'num_nearest_neighbours': 3,
#                                          'source_mask_attr_name': None,
#                                          'target_mask_attr_name': None}],
#                       'source_name': '${graph.hidden}',
#                       'target_name': '${graph.data}'}],
#            'hidden': 'hidden',
#            'nodes': {'data': {'attributes': '${graph.attributes.nodes}',
#                               'node_builder': {'_target_': 'anemoi.graphs.nodes.AnemoiDatasetNodes',
#                                                'dataset': '${dataloader.dataset}'}},
#                      'hidden': {'attributes': '${graph.attributes.nodes}',
#                                 'node_builder': {'_target_': 'anemoi.graphs.nodes.TriNodes',
#                                                  'resolution': 5}}},
#            'overwrite': True,
#            'post_processors': []},
#  'hardware': {'accelerator': 'auto',
#               'files': {'checkpoint': {'every_n_epochs': 'anemoi-by_epoch-epoch_{epoch:03d}-step_{step:06d}',
#                                        'every_n_minutes': 'anemoi-by_time-epoch_{epoch:03d}-step_{step:06d}',
#                                        'every_n_train_steps': 'anemoi-by_step-epoch_{epoch:03d}-step_{step:06d}'},
#                         'dataset': '???',
#                         'graph': '???',
#                         'truncation': None,
#                         'truncation_inv': None,
#                         'warm_start': None},
#               'num_gpus_per_model': 1,
#               'num_gpus_per_node': 1,
#               'num_nodes': 1,
#               'paths': {'checkpoints': '${hardware.paths.output}checkpoint/',
#                         'data': '???',
#                         'graph': '${hardware.paths.output}graphs/',
#                         'logs': {'base': '${hardware.paths.output}logs/',
#                                  'mlflow': '${hardware.paths.logs.base}mlflow/',
#                                  'tensorboard': '${hardware.paths.logs.base}tensorboard/',
#                                  'wandb': '${hardware.paths.logs.base}'},
#                         'output': '???',
#                         'plots': '${hardware.paths.output}plots/',
#                         'profiler': '${hardware.paths.output}profiler/',
#                         'truncation': None,
#                         'warm_start': None}},
#  'model': {'attributes': {'edges': ['edge_length', 'edge_dirs'], 'nodes': []},
#            'bounding': [{'_target_': 'anemoi.models.layers.bounding.ReluBounding',
#                          'variables': ['tp']}],
#            'cpu_offload': False,
#            'decoder': {'_target_': 'anemoi.models.layers.mapper.GNNBackwardMapper',
#                        'cpu_offload': '${model.cpu_offload}',
#                        'layer_kernels': '${model.layer_kernels}',
#                        'mlp_extra_layers': 0,
#                        'num_chunks': 1,
#                        'sub_graph_edge_attributes': '${model.attributes.edges}',
#                        'trainable_size': '${model.trainable_parameters.hidden2data}'},
#            'encoder': {'_target_': 'anemoi.models.layers.mapper.GNNForwardMapper',
#                        'cpu_offload': '${model.cpu_offload}',
#                        'layer_kernels': '${model.layer_kernels}',
#                        'mlp_extra_layers': 0,
#                        'num_chunks': 1,
#                        'sub_graph_edge_attributes': '${model.attributes.edges}',
#                        'trainable_size': '${model.trainable_parameters.data2hidden}'},
#            'keep_batch_sharded': True,
#            'layer_kernels': {'Activation': {'_target_': 'torch.nn.GELU'},
#                              'LayerNorm': {'_target_': 'anemoi.models.layers.normalization.AutocastLayerNorm'},
#                              'Linear': {'_target_': 'torch.nn.Linear'}},
#            'model': {'_target_': 'anemoi.models.models.AnemoiModelEncProcDec'},
#            'num_channels': 512,
#            'output_mask': {'_target_': 'anemoi.training.utils.masks.NoOutputMask'},
#            'processor': {'_target_': 'anemoi.models.layers.processor.GNNProcessor',
#                          'cpu_offload': '${model.cpu_offload}',
#                          'layer_kernels': '${model.layer_kernels}',
#                          'mlp_extra_layers': 0,
#                          'num_chunks': 2,
#                          'num_layers': 16,
#                          'sub_graph_edge_attributes': '${model.attributes.edges}',
#                          'trainable_size': '${model.trainable_parameters.hidden2hidden}'},
#            'trainable_parameters': {'data': 8,
#                                     'data2hidden': 8,
#                                     'hidden': 8,
#                                     'hidden2data': 8,
#                                     'hidden2hidden': 8}},
#  'training': {'accum_grad_batches': 1,
#               'deterministic': False,
#               'fork_run_id': None,
#               'gradient_clip': {'algorithm': 'value', 'val': 32.0},
#               'load_weights_only': False,
#               'loss_gradient_scaling': False,
#               'lr': {'iterations': '${training.max_steps}',
#                      'min': 3e-07,
#                      'rate': 6.25e-05,
#                      'warmup': 1000},
#               'max_epochs': None,
#               'max_steps': 150000,
#               'metrics': ['z_500', 't_850', 'u_850', 'v_850'],
#               'model_task': 'anemoi.training.train.tasks.GraphForecaster',
#               'multistep_input': 2,
#               'num_sanity_val_steps': 6,
#               'optimizer': {'kwargs': {'betas': [0.9, 0.95]}, 'zero': False},
#               'precision': '16-mixed',
#               'rollout': {'epoch_increment': 0, 'max': 1, 'start': 1},
#               'run_id': None,
#               'scalers': {'general_variable': {'_target_': 'anemoi.training.losses.scalers.GeneralVariableLossScaler',
#                                                'weights': {'10u': 0.1,
#                                                            '10v': 0.1,
#                                                            '2d': 0.5,
#                                                            'cp': 0.0025,
#                                                            'default': 1,
#                                                            'q': 0.6,
#                                                            'sp': 10,
#                                                            't': 6,
#                                                            'tp': 0.025,
#                                                            'u': 0.8,
#                                                            'v': 0.5,
#                                                            'w': 0.001,
#                                                            'z': 12}},
#                           'nan_mask_weights': {'_target_': 'anemoi.training.losses.scalers.NaNMaskScaler'},
#                           'node_weights': {'_target_': 'anemoi.training.losses.scalers.GraphNodeAttributeScaler',
#                                            'nodes_attribute_name': 'area_weight',
#                                            'nodes_name': '${graph.data}',
#                                            'norm': 'unit-sum'},
#                           'pressure_level': {'_target_': 'anemoi.training.losses.scalers.ReluVariableLevelScaler',
#                                              'group': 'pl',
#                                              'slope': 0.001,
#                                              'y_intercept': 0.2},
#                           'stdev_tendency': {'_target_': 'anemoi.training.losses.scalers.StdevTendencyScaler'},
#                           'var_tendency': {'_target_': 'anemoi.training.losses.scalers.VarTendencyScaler'}},
#               'strategy': {'_target_': 'anemoi.training.distributed.strategy.DDPGroupStrategy',
#                            'num_gpus_per_model': '${hardware.num_gpus_per_model}',
#                            'read_group_size': '${dataloader.read_group_size}'},
#               'submodules_to_freeze': [],
#               'swa': {'enabled': False, 'lr': 0.0001},
#               'training_loss': {'_target_': 'anemoi.training.losses.MSELoss',
#                                 'ignore_nans': False,
#                                 'scalers': ['pressure_level',
#                                             'general_variable',
#                                             'nan_mask_weights',
#                                             'node_weights']},
#               'transfer_learning': False,
#               'validation_metrics': {'mse': {'_target_': 'anemoi.training.losses.MSELoss',
#                                              'ignore_nans': True,
#                                              'scalers': ['node_weights']}},
#               'variable_groups': {'default': 'sfc',
#                                   'pl': {'param': ['q',
#                                                    't',
#                                                    'u',
#                                                    'v',
#                                                    'w',
#                                                    'z']}}}}

# %% [markdown]
# That's a long configuration! The advantage of composing configurations like this is that we can replace entire sections with a single line change. For instance, let's say we want to use a transformer model instead of a GNN. Both are defined respectively as YAML files `transformer.yaml` and `gnn.yaml` under `configs/training/model`. All we need to do is change `defaults.model` to `transformer`.

# %%
config["defaults"][6]["model"] = "transformer"

pprint(config)
# Out:
# {'config_validation': True,
#  'defaults': [{'data': 'zarr'},
#               {'dataloader': 'native_grid'},
#               {'diagnostics': 'evaluation'},
#               {'datamodule': 'single'},
#               {'hardware': 'example'},
#               {'graph': 'multi_scale'},
#               {'model': 'transformer'},
#               {'training': 'default'},
#               '_self_']}

# %% [markdown]
# Configuring anemoi-training also supports interpolating values inside the config. For instance, let's look at the dataloader config

# %%
pprint(OmegaConf.to_container(composed_config["dataloader"]))
# Out:
# {'batch_size': {'test': 4, 'training': 2, 'validation': 4},
#  'dataset': '${hardware.paths.data}/${hardware.files.dataset}',
#  'grid_indices': {'_target_': 'anemoi.training.data.grid_indices.FullGrid',
#                   'nodes_name': '${graph.data}'},
#  'limit_batches': {'test': 20, 'training': None, 'validation': None},
#  'num_workers': {'test': 8, 'training': 8, 'validation': 8},
#  'pin_memory': True,
#  'prefetch_factor': 2,
#  'read_group_size': '${hardware.num_gpus_per_model}',
#  'test': {'dataset': '${dataloader.dataset}',
#           'drop': [],
#           'end': None,
#           'frequency': '${data.frequency}',
#           'start': 2022},
#  'training': {'dataset': '${dataloader.dataset}',
#               'drop': [],
#               'end': 2020,
#               'frequency': '${data.frequency}',
#               'start': None},
#  'validation': {'dataset': '${dataloader.dataset}',
#                 'drop': [],
#                 'end': 2021,
#                 'frequency': '${data.frequency}',
#                 'start': 2021},
#  'validation_rollout': 1}

# %% [markdown]
# The dataloader config `dataset` entry is `${hardware.paths.data}/${hardware.files.dataset}`. This means that the value will be taken from other parts of the config. Let's go have a look.

# %%
composed_config["hardware"]["paths"]["data"]
# Out:
# ---------------------------------------------------------------------------
# MissingMandatoryValue                     Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 composed_config["hardware"]["paths"]["data"]
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/dictconfig.py:375, in DictConfig.__getitem__(self, key)
#     371     self._format_and_raise(
#     372         key=key, value=None, cause=e, type_override=ConfigKeyError
#     373     )
#     374 except Exception as e:
# --> 375     self._format_and_raise(key=key, value=None, cause=e)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:231, in Node._format_and_raise(self, key, value, cause, msg, type_override)
#     223 def _format_and_raise(
#     224     self,
#     225     key: Any,
#    (...)    229     type_override: Any = None,
#     230 ) -> None:
# --> 231     format_and_raise(
#     232         node=self,
#     233         key=key,
#     234         value=value,
#     235         msg=str(cause) if msg is None else msg,
#     236         cause=cause,
#     237         type_override=type_override,
#     238     )
#     239     assert False
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:899, in format_and_raise(node, key, value, msg, cause, type_override)
#     896     ex.ref_type = ref_type
#     897     ex.ref_type_str = ref_type_str
# --> 899 _raise(ex, cause)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:797, in _raise(ex, cause)
#     795 else:
#     796     ex.__cause__ = None
# --> 797 raise ex.with_traceback(sys.exc_info()[2])
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/dictconfig.py:369, in DictConfig.__getitem__(self, key)
#     362 """
#     363 Allow map style access
#     364 :param key:
#     365 :return:
#     366 """
#     368 try:
# --> 369     return self._get_impl(key=key, default_value=_DEFAULT_MARKER_)
#     370 except AttributeError as e:
#     371     self._format_and_raise(
#     372         key=key, value=None, cause=e, type_override=ConfigKeyError
#     373     )
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/dictconfig.py:451, in DictConfig._get_impl(self, key, default_value, validate_key)
#     449         raise
#     450 assert isinstance(node, Node)
# --> 451 return self._resolve_with_default(
#     452     key=key, value=node, default_value=default_value
#     453 )
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:96, in BaseContainer._resolve_with_default(self, key, value, default_value)
#      94     if default_value is not _DEFAULT_MARKER_:
#      95         return default_value
# ---> 96     raise MissingMandatoryValue("Missing mandatory value: $FULL_KEY")
#      98 resolved_node = self._maybe_resolve_interpolation(
#      99     parent=self,
#     100     key=key,
#     101     value=value,
#     102     throw_on_resolution_failure=True,
#     103 )
#     105 return _get_value(resolved_node)
#
# MissingMandatoryValue: Missing mandatory value: hardware.paths.data
#     full_key: hardware.paths.data
#     object_type=dict

# %% [markdown]
# we haven't set this one. This is why, when we try to resolve the full configuration (in other words, to interpolate all values with the ${value} syntax), we get an error:

# %%
# note 'resolve=True' argument
OmegaConf.to_container(composed_config, resolve=True)
# Out:
# ---------------------------------------------------------------------------
# InterpolationToMissingValueError          Traceback (most recent call last)
# Cell In[40], line 2
#       1 # note 'resolve=True' argument
# ----> 2 OmegaConf.to_container(composed_config, resolve=True)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/omegaconf.py:573, in OmegaConf.to_container(cfg, resolve, throw_on_missing, enum_to_str, structured_config_mode)
#     568 if not OmegaConf.is_config(cfg):
#     569     raise ValueError(
#     570         f"Input cfg is not an OmegaConf config object ({type_str(type(cfg))})"
#     571     )
# --> 573 return BaseContainer._to_content(
#     574     cfg,
#     575     resolve=resolve,
#     576     throw_on_missing=throw_on_missing,
#     577     enum_to_str=enum_to_str,
#     578     structured_config_mode=structured_config_mode,
#     579 )
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:292, in BaseContainer._to_content(conf, resolve, throw_on_missing, enum_to_str, structured_config_mode)
#     290 retdict: Dict[DictKeyType, Any] = {}
#     291 for key in conf.keys():
# --> 292     value = get_node_value(key)
#     293     if enum_to_str and isinstance(key, Enum):
#     294         key = f"{key.name}"
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:247, in BaseContainer._to_content.<locals>.get_node_value(key)
#     244         conf._format_and_raise(key=key, value=None, cause=e)
#     246 if isinstance(node, Container):
# --> 247     value = BaseContainer._to_content(
#     248         node,
#     249         resolve=resolve,
#     250         throw_on_missing=throw_on_missing,
#     251         enum_to_str=enum_to_str,
#     252         structured_config_mode=structured_config_mode,
#     253     )
#     254 else:
#     255     value = convert(node)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:292, in BaseContainer._to_content(conf, resolve, throw_on_missing, enum_to_str, structured_config_mode)
#     290 retdict: Dict[DictKeyType, Any] = {}
#     291 for key in conf.keys():
# --> 292     value = get_node_value(key)
#     293     if enum_to_str and isinstance(key, Enum):
#     294         key = f"{key.name}"
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:244, in BaseContainer._to_content.<locals>.get_node_value(key)
#     242         node = node._dereference_node()
#     243     except InterpolationResolutionError as e:
# --> 244         conf._format_and_raise(key=key, value=None, cause=e)
#     246 if isinstance(node, Container):
#     247     value = BaseContainer._to_content(
#     248         node,
#     249         resolve=resolve,
#    (...)    252         structured_config_mode=structured_config_mode,
#     253     )
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:231, in Node._format_and_raise(self, key, value, cause, msg, type_override)
#     223 def _format_and_raise(
#     224     self,
#     225     key: Any,
#    (...)    229     type_override: Any = None,
#     230 ) -> None:
# --> 231     format_and_raise(
#     232         node=self,
#     233         key=key,
#     234         value=value,
#     235         msg=str(cause) if msg is None else msg,
#     236         cause=cause,
#     237         type_override=type_override,
#     238     )
#     239     assert False
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:899, in format_and_raise(node, key, value, msg, cause, type_override)
#     896     ex.ref_type = ref_type
#     897     ex.ref_type_str = ref_type_str
# --> 899 _raise(ex, cause)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:797, in _raise(ex, cause)
#     795 else:
#     796     ex.__cause__ = None
# --> 797 raise ex.with_traceback(sys.exc_info()[2])
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:242, in BaseContainer._to_content.<locals>.get_node_value(key)
#     240 if resolve:
#     241     try:
# --> 242         node = node._dereference_node()
#     243     except InterpolationResolutionError as e:
#     244         conf._format_and_raise(key=key, value=None, cause=e)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:246, in Node._dereference_node(self)
#     245 def _dereference_node(self) -> "Node":
# --> 246     node = self._dereference_node_impl(throw_on_resolution_failure=True)
#     247     assert node is not None
#     248     return node
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:277, in Node._dereference_node_impl(self, throw_on_resolution_failure, memo)
#     275 assert parent is not None
#     276 key = self._key()
# --> 277 return parent._resolve_interpolation_from_parse_tree(
#     278     parent=parent,
#     279     key=key,
#     280     value=self,
#     281     parse_tree=parse(_get_value(self)),
#     282     throw_on_resolution_failure=throw_on_resolution_failure,
#     283     memo=memo,
#     284 )
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:584, in Container._resolve_interpolation_from_parse_tree(self, parent, value, key, parse_tree, throw_on_resolution_failure, memo)
#     554 """
#     555 Resolve an interpolation.
#     556
#    (...)    580     `throw_on_resolution_failure` is `False` and an error occurs during resolution.
#     581 """
#     583 try:
# --> 584     resolved = self.resolve_parse_tree(
#     585         parse_tree=parse_tree, node=value, key=key, memo=memo
#     586     )
#     587 except InterpolationResolutionError:
#     588     if throw_on_resolution_failure:
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:764, in Container.resolve_parse_tree(self, parse_tree, node, memo, key)
#     758 visitor = GrammarVisitor(
#     759     node_interpolation_callback=node_interpolation_callback,
#     760     resolver_interpolation_callback=resolver_interpolation_callback,
#     761     memo=memo,
#     762 )
#     763 try:
# --> 764     return visitor.visit(parse_tree)
#     765 except InterpolationResolutionError:
#     766     raise
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:206, in OmegaConfGrammarParser.ConfigValueContext.accept(self, visitor)
#     204 def accept(self, visitor:ParseTreeVisitor):
#     205     if hasattr( visitor, "visitConfigValue" ):
# --> 206         return visitor.visitConfigValue(self)
#     207     else:
#     208         return visitor.visitChildren(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:101, in GrammarVisitor.visitConfigValue(self, ctx)
#      98 def visitConfigValue(self, ctx: OmegaConfGrammarParser.ConfigValueContext) -> Any:
#      99     # text EOF
#     100     assert ctx.getChildCount() == 2
# --> 101     return self.visit(ctx.getChild(0))
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:342, in OmegaConfGrammarParser.TextContext.accept(self, visitor)
#     340 def accept(self, visitor:ParseTreeVisitor):
#     341     if hasattr( visitor, "visitText" ):
# --> 342         return visitor.visitText(self)
#     343     else:
#     344         return visitor.visitChildren(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:301, in GrammarVisitor.visitText(self, ctx)
#     298         return self.visitInterpolation(c)
#     300 # Otherwise, concatenate string representations together.
# --> 301 return self._unescape(list(ctx.getChildren()))
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:389, in GrammarVisitor._unescape(self, seq)
#     387     else:
#     388         assert isinstance(node, OmegaConfGrammarParser.InterpolationContext)
# --> 389         text = str(self.visitInterpolation(node))
#     390     chrs.append(text)
#     392 return "".join(chrs)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:125, in GrammarVisitor.visitInterpolation(self, ctx)
#     121 def visitInterpolation(
#     122     self, ctx: OmegaConfGrammarParser.InterpolationContext
#     123 ) -> Any:
#     124     assert ctx.getChildCount() == 1  # interpolationNode | interpolationResolver
# --> 125     return self.visit(ctx.getChild(0))
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:921, in OmegaConfGrammarParser.InterpolationNodeContext.accept(self, visitor)
#     919 def accept(self, visitor:ParseTreeVisitor):
#     920     if hasattr( visitor, "visitInterpolationNode" ):
# --> 921         return visitor.visitInterpolationNode(self)
#     922     else:
#     923         return visitor.visitChildren(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:158, in GrammarVisitor.visitInterpolationNode(self, ctx)
#     155         inter_key_tokens.append(self.visitConfigKey(child))
#     157 inter_key = "".join(inter_key_tokens)
# --> 158 return self.node_interpolation_callback(inter_key, self.memo)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:745, in Container.resolve_parse_tree.<locals>.node_interpolation_callback(inter_key, memo)
#     742 def node_interpolation_callback(
#     743     inter_key: str, memo: Optional[Set[int]]
#     744 ) -> Optional["Node"]:
# --> 745     return self._resolve_node_interpolation(inter_key=inter_key, memo=memo)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:671, in Container._resolve_node_interpolation(self, inter_key, memo)
#     664     parent, last_key, value = root_node._select_impl(
#     665         inter_key,
#     666         throw_on_missing=True,
#     667         throw_on_resolution_failure=True,
#     668         memo=memo,
#     669     )
#     670 except MissingMandatoryValue as exc:
# --> 671     raise InterpolationToMissingValueError(
#     672         f"MissingMandatoryValue while resolving interpolation: {exc}"
#     673     ).with_traceback(sys.exc_info()[2])
#     675 if parent is None or value is None:
#     676     raise InterpolationKeyError(f"Interpolation key '{inter_key}' not found")
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:664, in Container._resolve_node_interpolation(self, inter_key, memo)
#     659     raise InterpolationKeyError(
#     660         f"ConfigKeyError while resolving interpolation: {exc}"
#     661     ).with_traceback(sys.exc_info()[2])
#     663 try:
# --> 664     parent, last_key, value = root_node._select_impl(
#     665         inter_key,
#     666         throw_on_missing=True,
#     667         throw_on_resolution_failure=True,
#     668         memo=memo,
#     669     )
#     670 except MissingMandatoryValue as exc:
#     671     raise InterpolationToMissingValueError(
#     672         f"MissingMandatoryValue while resolving interpolation: {exc}"
#     673     ).with_traceback(sys.exc_info()[2])
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:514, in Container._select_impl(self, key, throw_on_missing, throw_on_resolution_failure, memo)
#     511     return None, None, None
#     513 last_key = split[-1]
# --> 514 value, _ = _select_one(
#     515     c=root,
#     516     key=last_key,
#     517     throw_on_missing=throw_on_missing,
#     518     throw_on_type_error=throw_on_resolution_failure,
#     519 )
#     520 if value is None:
#     521     return root, last_key, None
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/omegaconf.py:1150, in _select_one(c, key, throw_on_missing, throw_on_type_error)
#    1148 if val._is_missing():
#    1149     if throw_on_missing:
# -> 1150         raise MissingMandatoryValue(
#    1151             f"Missing mandatory value: {c._get_full_key(ret_key)}"
#    1152         )
#    1153     else:
#    1154         return val, ret_key
#
# InterpolationToMissingValueError: MissingMandatoryValue while resolving interpolation: Missing mandatory value: hardware.paths.data
#     full_key: dataloader.dataset
#     object_type=dict

# %% [markdown]
# There are a few other values that have no defaults:

# %%
# !grep "???" -r ../configs/training
# Out:
# ../configs/training/stretched.yaml:        thinning: ???
# ../configs/training/stretched.yaml:      weight_frac_of_total: ???
# ../configs/training/stretched.yaml:    dataset: ???
# ../configs/training/stretched.yaml:    forcing_dataset: ???
# ../configs/training/training/scalers/stretched.yaml:  weight_frac_of_total: ???
# ../configs/training/diagnostics/evaluation.yaml:    entity: ???
# ../configs/training/hardware/files/example.yaml:dataset: ???
# ../configs/training/hardware/files/example.yaml:graph: ???
# ../configs/training/hardware/paths/example.yaml:data: ???
# ../configs/training/hardware/paths/example.yaml:output: ???
# ../configs/training/lam.yaml:        thinning: ???
# ../configs/training/lam.yaml:    dataset: ???
# ../configs/training/lam.yaml:    forcing_dataset: ???

# %% [markdown]
# however, the ones that are absolutely needed to run a training are the following:
#
# - `hardware.paths.data`: Location of base directory where datasets are stored.
# - `hardware.paths.graph`: Location of graph directory. You can set this to where you stored your generated graph: `../output/graphs`.
# - `hardware.paths.output`: Location of output directory. Set this to `../output/training`.
# - `hardware.files.dataset`: Filename(s) of datasets used for training.
# - `hardware.files.graph`: If you have pre-computed a specific graph, specify its filename here. Otherwise, a new graph will be constructed on the fly and written to the filename given.
#
#
# Under `../configs/training/hardware` we can find some example configs that will help us. Let's set some values directly in our config.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

# set all the mandatory missing config entries
config["hardware"] = {
    "paths": {
        "data": str(PROJECT_ROOT / "output/datasets"),
        "graph": str(PROJECT_ROOT / "output/graphs"),
        "output": str(PROJECT_ROOT / "output/training"),
    },
    "files": {
        "dataset": "aifs-ea-an-oper-0001-mars-o96-1979-2022-6h-v6.zarr",
        "graph": "o96_multi_scale.pt",
    }
}

# set some extra config entries
config["defaults"][4]["hardware"] = "slurm"

# in this demo we use small batch sizes, but consider that in any case we will 
# be using distributed training across multiple GPUs, so the effective batch size will be
# (num_gpus * batch_size_per_gpu)
config["dataloader"] = {
    "batch_size": {
        "training": 1,
        "validation": 1
    }
}

# %% [markdown]
# We save the config now.

# %%
with open("../configs/training/demo.yaml", "w") as f:
    yaml.dump(config, f, sort_keys=False)

# %% [markdown]
# Let's check that we can compose and resolve it:

# %%
composed_config = compose_config("../configs/training", "demo")
pprint(OmegaConf.to_container(composed_config, resolve=True))
# Out:
# ---------------------------------------------------------------------------
# InterpolationResolutionError              Traceback (most recent call last)
# Cell In[48], line 2
#       1 composed_config = compose_config("../configs/training", "demo")
# ----> 2 pprint(OmegaConf.to_container(composed_config, resolve=True))
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/omegaconf.py:573, in OmegaConf.to_container(cfg, resolve, throw_on_missing, enum_to_str, structured_config_mode)
#     568 if not OmegaConf.is_config(cfg):
#     569     raise ValueError(
#     570         f"Input cfg is not an OmegaConf config object ({type_str(type(cfg))})"
#     571     )
# --> 573 return BaseContainer._to_content(
#     574     cfg,
#     575     resolve=resolve,
#     576     throw_on_missing=throw_on_missing,
#     577     enum_to_str=enum_to_str,
#     578     structured_config_mode=structured_config_mode,
#     579 )
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:292, in BaseContainer._to_content(conf, resolve, throw_on_missing, enum_to_str, structured_config_mode)
#     290 retdict: Dict[DictKeyType, Any] = {}
#     291 for key in conf.keys():
# --> 292     value = get_node_value(key)
#     293     if enum_to_str and isinstance(key, Enum):
#     294         key = f"{key.name}"
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:247, in BaseContainer._to_content.<locals>.get_node_value(key)
#     244         conf._format_and_raise(key=key, value=None, cause=e)
#     246 if isinstance(node, Container):
# --> 247     value = BaseContainer._to_content(
#     248         node,
#     249         resolve=resolve,
#     250         throw_on_missing=throw_on_missing,
#     251         enum_to_str=enum_to_str,
#     252         structured_config_mode=structured_config_mode,
#     253     )
#     254 else:
#     255     value = convert(node)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:292, in BaseContainer._to_content(conf, resolve, throw_on_missing, enum_to_str, structured_config_mode)
#     290 retdict: Dict[DictKeyType, Any] = {}
#     291 for key in conf.keys():
# --> 292     value = get_node_value(key)
#     293     if enum_to_str and isinstance(key, Enum):
#     294         key = f"{key.name}"
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:244, in BaseContainer._to_content.<locals>.get_node_value(key)
#     242         node = node._dereference_node()
#     243     except InterpolationResolutionError as e:
# --> 244         conf._format_and_raise(key=key, value=None, cause=e)
#     246 if isinstance(node, Container):
#     247     value = BaseContainer._to_content(
#     248         node,
#     249         resolve=resolve,
#    (...)    252         structured_config_mode=structured_config_mode,
#     253     )
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:231, in Node._format_and_raise(self, key, value, cause, msg, type_override)
#     223 def _format_and_raise(
#     224     self,
#     225     key: Any,
#    (...)    229     type_override: Any = None,
#     230 ) -> None:
# --> 231     format_and_raise(
#     232         node=self,
#     233         key=key,
#     234         value=value,
#     235         msg=str(cause) if msg is None else msg,
#     236         cause=cause,
#     237         type_override=type_override,
#     238     )
#     239     assert False
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:899, in format_and_raise(node, key, value, msg, cause, type_override)
#     896     ex.ref_type = ref_type
#     897     ex.ref_type_str = ref_type_str
# --> 899 _raise(ex, cause)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/_utils.py:797, in _raise(ex, cause)
#     795 else:
#     796     ex.__cause__ = None
# --> 797 raise ex.with_traceback(sys.exc_info()[2])
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/basecontainer.py:242, in BaseContainer._to_content.<locals>.get_node_value(key)
#     240 if resolve:
#     241     try:
# --> 242         node = node._dereference_node()
#     243     except InterpolationResolutionError as e:
#     244         conf._format_and_raise(key=key, value=None, cause=e)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:246, in Node._dereference_node(self)
#     245 def _dereference_node(self) -> "Node":
# --> 246     node = self._dereference_node_impl(throw_on_resolution_failure=True)
#     247     assert node is not None
#     248     return node
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:277, in Node._dereference_node_impl(self, throw_on_resolution_failure, memo)
#     275 assert parent is not None
#     276 key = self._key()
# --> 277 return parent._resolve_interpolation_from_parse_tree(
#     278     parent=parent,
#     279     key=key,
#     280     value=self,
#     281     parse_tree=parse(_get_value(self)),
#     282     throw_on_resolution_failure=throw_on_resolution_failure,
#     283     memo=memo,
#     284 )
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:584, in Container._resolve_interpolation_from_parse_tree(self, parent, value, key, parse_tree, throw_on_resolution_failure, memo)
#     554 """
#     555 Resolve an interpolation.
#     556
#    (...)    580     `throw_on_resolution_failure` is `False` and an error occurs during resolution.
#     581 """
#     583 try:
# --> 584     resolved = self.resolve_parse_tree(
#     585         parse_tree=parse_tree, node=value, key=key, memo=memo
#     586     )
#     587 except InterpolationResolutionError:
#     588     if throw_on_resolution_failure:
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:769, in Container.resolve_parse_tree(self, parse_tree, node, memo, key)
#     766     raise
#     767 except Exception as exc:
#     768     # Other kinds of exceptions are wrapped in an `InterpolationResolutionError`.
# --> 769     raise InterpolationResolutionError(
#     770         f"{type(exc).__name__} raised while resolving interpolation: {exc}"
#     771     ).with_traceback(sys.exc_info()[2])
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:764, in Container.resolve_parse_tree(self, parse_tree, node, memo, key)
#     758 visitor = GrammarVisitor(
#     759     node_interpolation_callback=node_interpolation_callback,
#     760     resolver_interpolation_callback=resolver_interpolation_callback,
#     761     memo=memo,
#     762 )
#     763 try:
# --> 764     return visitor.visit(parse_tree)
#     765 except InterpolationResolutionError:
#     766     raise
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:206, in OmegaConfGrammarParser.ConfigValueContext.accept(self, visitor)
#     204 def accept(self, visitor:ParseTreeVisitor):
#     205     if hasattr( visitor, "visitConfigValue" ):
# --> 206         return visitor.visitConfigValue(self)
#     207     else:
#     208         return visitor.visitChildren(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:101, in GrammarVisitor.visitConfigValue(self, ctx)
#      98 def visitConfigValue(self, ctx: OmegaConfGrammarParser.ConfigValueContext) -> Any:
#      99     # text EOF
#     100     assert ctx.getChildCount() == 2
# --> 101     return self.visit(ctx.getChild(0))
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:342, in OmegaConfGrammarParser.TextContext.accept(self, visitor)
#     340 def accept(self, visitor:ParseTreeVisitor):
#     341     if hasattr( visitor, "visitText" ):
# --> 342         return visitor.visitText(self)
#     343     else:
#     344         return visitor.visitChildren(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:298, in GrammarVisitor.visitText(self, ctx)
#     296     c = ctx.getChild(0)
#     297     if isinstance(c, OmegaConfGrammarParser.InterpolationContext):
# --> 298         return self.visitInterpolation(c)
#     300 # Otherwise, concatenate string representations together.
#     301 return self._unescape(list(ctx.getChildren()))
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:125, in GrammarVisitor.visitInterpolation(self, ctx)
#     121 def visitInterpolation(
#     122     self, ctx: OmegaConfGrammarParser.InterpolationContext
#     123 ) -> Any:
#     124     assert ctx.getChildCount() == 1  # interpolationNode | interpolationResolver
# --> 125     return self.visit(ctx.getChild(0))
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:1041, in OmegaConfGrammarParser.InterpolationResolverContext.accept(self, visitor)
#    1039 def accept(self, visitor:ParseTreeVisitor):
#    1040     if hasattr( visitor, "visitInterpolationResolver" ):
# -> 1041         return visitor.visitInterpolationResolver(self)
#    1042     else:
#    1043         return visitor.visitChildren(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:175, in GrammarVisitor.visitInterpolationResolver(self, ctx)
#     173 else:
#     174     assert isinstance(maybe_seq, OmegaConfGrammarParser.SequenceContext)
# --> 175     for val, txt in self.visitSequence(maybe_seq):
#     176         args.append(val)
#     177         args_str.append(txt)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:267, in GrammarVisitor.visitSequence(self, ctx)
#     261 for child in ctx.getChildren():
#     262     if isinstance(child, OmegaConfGrammarParser.ElementContext):
#     263         # Also preserve the original text representation of `child` so
#     264         # as to allow backward compatibility with old resolvers (registered
#     265         # with `legacy_register_resolver()`). Note that we cannot just cast
#     266         # the value to string later as for instance `null` would become "None".
# --> 267         yield _get_value(self.visitElement(child)), child.getText()
#     268         is_previous_comma = False
#     269     else:
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:119, in GrammarVisitor.visitElement(self, ctx)
#     116 def visitElement(self, ctx: OmegaConfGrammarParser.ElementContext) -> Any:
#     117     # primitive | quotedValue | listContainer | dictContainer
#     118     assert ctx.getChildCount() == 1
# --> 119     return self.visit(ctx.getChild(0))
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:1406, in OmegaConfGrammarParser.PrimitiveContext.accept(self, visitor)
#    1404 def accept(self, visitor:ParseTreeVisitor):
#    1405     if hasattr( visitor, "visitPrimitive" ):
# -> 1406         return visitor.visitPrimitive(self)
#    1407     else:
#    1408         return visitor.visitChildren(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:212, in GrammarVisitor.visitPrimitive(self, ctx)
#     211 def visitPrimitive(self, ctx: OmegaConfGrammarParser.PrimitiveContext) -> Any:
# --> 212     return self._createPrimitive(ctx)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:314, in GrammarVisitor._createPrimitive(self, ctx)
#     312 child = ctx.getChild(0)
#     313 if isinstance(child, OmegaConfGrammarParser.InterpolationContext):
# --> 314     return self.visitInterpolation(child)
#     315 assert isinstance(child, TerminalNode)
#     316 symbol = child.symbol
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:125, in GrammarVisitor.visitInterpolation(self, ctx)
#     121 def visitInterpolation(
#     122     self, ctx: OmegaConfGrammarParser.InterpolationContext
#     123 ) -> Any:
#     124     assert ctx.getChildCount() == 1  # interpolationNode | interpolationResolver
# --> 125     return self.visit(ctx.getChild(0))
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/antlr4/tree/Tree.py:34, in ParseTreeVisitor.visit(self, tree)
#      33 def visit(self, tree):
# ---> 34     return tree.accept(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar/gen/OmegaConfGrammarParser.py:1041, in OmegaConfGrammarParser.InterpolationResolverContext.accept(self, visitor)
#    1039 def accept(self, visitor:ParseTreeVisitor):
#    1040     if hasattr( visitor, "visitInterpolationResolver" ):
# -> 1041         return visitor.visitInterpolationResolver(self)
#    1042     else:
#    1043         return visitor.visitChildren(self)
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/grammar_visitor.py:179, in GrammarVisitor.visitInterpolationResolver(self, ctx)
#     176         args.append(val)
#     177         args_str.append(txt)
# --> 179 return self.resolver_interpolation_callback(
#     180     name=resolver_name,
#     181     args=tuple(args),
#     182     args_str=tuple(args_str),
#     183 )
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:750, in Container.resolve_parse_tree.<locals>.resolver_interpolation_callback(name, args, args_str)
#     747 def resolver_interpolation_callback(
#     748     name: str, args: Tuple[Any, ...], args_str: Tuple[str, ...]
#     749 ) -> Any:
# --> 750     return self._evaluate_custom_resolver(
#     751         key=key,
#     752         node=node,
#     753         inter_type=name,
#     754         inter_args=args,
#     755         inter_args_str=args_str,
#     756     )
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/base.py:694, in Container._evaluate_custom_resolver(self, key, node, inter_type, inter_args, inter_args_str)
#     692 if resolver is not None:
#     693     root_node = self._get_root()
# --> 694     return resolver(
#     695         root_node,
#     696         self,
#     697         node,
#     698         inter_args,
#     699         inter_args_str,
#     700     )
#     701 else:
#     702     raise UnsupportedInterpolationType(
#     703         f"Unsupported interpolation type {inter_type}"
#     704     )
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/omegaconf.py:445, in OmegaConf.register_new_resolver.<locals>.resolver_wrapper(config, parent, node, args, args_str)
#     442 if pass_root:
#     443     kwargs["_root_"] = config
# --> 445 ret = resolver(*args, **kwargs)
#     447 if use_cache:
#     448     cache[args_str] = ret
#
# File /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/.venv/lib/python3.12/site-packages/omegaconf/resolvers/oc/__init__.py:38, in env(key, default)
#      36     return str(default) if default is not None else None
#      37 else:
# ---> 38     raise KeyError(f"Environment variable '{key}' not found")
#
# InterpolationResolutionError: KeyError raised while resolving interpolation: "Environment variable 'SLURM_GPUS_PER_NODE' not found"
#     full_key: hardware.num_gpus_per_node
#     object_type=dict

# %% [markdown]
# We are getting this error because some of the keys are configured to be resolved via environment variables, for instance:

# %%
composed_config = OmegaConf.to_container(composed_config, resolve=False)
composed_config["hardware"]["num_gpus_per_node"]
# Out:
# '${oc.decode:${oc.env:SLURM_GPUS_PER_NODE}}'

# %% [markdown]
# This is expected, because in our config we are using a pre-defined `slurm` config for hardware's defaults. This config can be used to launch training programs on SLURM clusters.
#
# One can of course create another default config for other cluster types, or manually override these values.

# %% [markdown]
# ## Launching the training program
#
# The training program can be launched from the command line, with
#
# ```bash
# anemoi-training train --config-path=/path/to/training/config/directory --config-name=demo.yaml
# ```
#
# one can also override some values directly from the command line:
#
# ```bash
# anemoi-training train \
#     --config-path=/path/to/training/config/directory \
#     --config-name=demo.yaml \
#     training.max_steps=100000
# ```
#
# Note that while launching program can like this be useful for debugging purposes, when one wants to launch full-scale training runs, a submission script is typically used. In this notebook we will focus on training on a SLURM cluster, for which we will use a submission script such as the one below. Note that SLURM job specification can be specific to your cluster, so you might have to do some updates.

# %% [markdown]
# ### Example SLURM submission script

# %% [markdown]
# In this case, we will be launching a distributed training over 8 nodes, with 4 GPUs per node. We will specify 4 tasks per node because pytorch's Distributed Data Parallel (DDP) model requires one process per GPU. In total we will have 24 GPUs so 24 processes.

# %%
SLURM_SUBMISSION_SCRIPT = """#!/bin/bash

#SBATCH --job-name="demo-anemoi-training"
#SBATCH --partition=normal
#SBATCH --nodes=8
#SBATCH --ntasks-per-node=4
#SBATCH --gpus-per-node=4
#SBATCH --cpus-per-task=16
#SBATCH --mem=256G
#SBATCH --time=12:00:00
#SBATCH --exclusive
#SBATCH --output=slogs/debug.log
#SBATCH --error=slogs/debug.err

CONFIG_DIR=$(realpath configs/training)
CONFIG_NAME="demo.yaml"

echo "=================================================="
echo "Submitting anemoi-training job to SLURM..."
echo "Using config dir: $CONFIG_DIR"
echo "Using config name: $CONFIG_NAME"
echo "=================================================="

srun -u anemoi-training train --config-path $CONFIG_DIR --config-name $CONFIG_NAME
"""

Path("../scripts").mkdir(exist_ok=True)
with open("../scripts/submit_slurm.sh", "w") as f:
    f.write(SLURM_SUBMISSION_SCRIPT)

# %%
# !cd ../ && sbatch scripts/submit_slurm.sh
# Out:
# /scratch/mch/fzanetta/projects/anemoi-demo-keisler2022/configs/training/demo.yaml

# %% [markdown]
# ## Tracking your experiments
#
# Anemoi supports two popular tools for tracking your experiments: MLFlow and W&B. In the anemoi community, MLFlow is currently considered the standard, so we will focus on that.
